# %%
import torch

n_bn = 2  # 1, 2, 4, 8, 16, 32
rep = 0  # 0, 1
model = 'imagenet_resnet50'

model = torch.hub.load('ecs-vlc/bottleneck:master', model, n_bn=n_bn, rep=rep)
print(model)
# Out:
# Downloading: "https://github.com/ecs-vlc/bottleneck/archive/master.zip" to /home/ethan/.cache/torch/hub/master.zip
# Downloading: "http://marc.ecs.soton.ac.uk/pytorch-models/opponency/resnet50/resnet50_2_0.pt" to /home/ethan/.cache/torch/hub/checkpoints/resnet50_2_0.pt
# ...
# RetinalBottleneckModel(
#   (retina): Sequential(
#     (retina_conv1): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (retina_relu1): ReLU()
#     (retina_conv2): Conv2d(32, 2, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (retina_relu2): ReLU()
#   )
#   (ventral): ResNet(
#     (conv1): Conv2d(2, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
# ...
